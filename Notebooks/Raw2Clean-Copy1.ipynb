# %%
import numpy as np
import pandas as pd

# %%
gt_df = pd.read_csv('/Users/jxhn/Desktop/IRONHACK/Week_5/Mid_bootcamp_project/Data/Raw/globalterrorismr.csv', encoding = 'ISO-8859-1')
# Out:
# /var/folders/h1/sm0yz6nx7m9cgsn8627qx6c00000gn/T/ipykernel_36057/2132931928.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   gt_df = pd.read_csv('/Users/jxhn/Desktop/IRONHACK/Week_5/Mid_bootcamp_project/Data/Raw/globalterrorismr.csv', encoding = 'ISO-8859-1')

# %%
gt_df #this is my dataframe at its massive
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
gt_df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
gt_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
gt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
print('Will be creating seperate dataframes for each category of questions')
# Out:
# Will be creating seperate dataframes for each category of questions

# %%
q1_df = gt_df[['iyear','imonth','iday','country_txt','region_txt','provstate','city','location','propvalue','summary','success','suicide','attacktype1_txt','targtype1_txt','targsubtype1_txt','corp1','target1','gname','motive','weapsubtype1_txt','weapdetail','propcomment','addnotes']]

# %%
q1_df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city location  propvalue summary  ...  \
# 0       NaN  Santo Domingo      NaN        NaN     NaN  ...
# 1   Federal    Mexico city      NaN        NaN     NaN  ...
# 2    Tarlac        Unknown      NaN        NaN     NaN  ...
# 3    Attica         Athens      NaN        NaN     NaN  ...
# 4   Fukouka        Fukouka      NaN        NaN     NaN  ...
#
#                  targtype1_txt  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# ...

# %%
sorted_q1_df = q1_df.sort_values(by='propvalue', ascending=False) #want to make a top 5 list of damaged occured

# %%
sorted_q1_df.head(5)
# Out:
#        iyear  imonth  iday     country_txt      region_txt provstate  \
# 50996   1992       4    10  United Kingdom  Western Europe   England
# 62651   1996       6    15  United Kingdom  Western Europe   England
# 59037   1995       4    19   United States   North America  Oklahoma
# 16681   1982       7    27            Peru   South America  Ayacucho
# 72475   2001       7    24       Sri Lanka      South Asia   Western
#
#                 city                                           location  \
# 50996         London                                                NaN
# 62651     Manchester  Corporation Street outside the Arndale shoppin...
# 59037  Oklahoma City                                                NaN
# 16681       Ayacucho                                                NaN
# 72475     Katunayake  The incident occurred at the Bandaranaike Inte...
#
#           propvalue                                            summary  ...  \
# ...

# %%
prop_column_values = sorted_q1_df['propvalue']

# %%
prop_column_values
# Out:
# 50996     2.700000e+09
# 62651     1.079120e+09
# 59037     6.520000e+08
# 16681     5.480000e+08
# 72475     3.500000e+08
#               ...
# 181683             NaN
# 181684             NaN
# 181686             NaN
# 181689             NaN
# 181690             NaN
# Name: propvalue, Length: 181691, dtype: float64

# %%
q1_df_5 = sorted_q1_df.head(5) #first I'll get the values I need and then clean the column

# %%
q1_df_5
# Out:
#        iyear  imonth  iday     country_txt      region_txt provstate  \
# 50996   1992       4    10  United Kingdom  Western Europe   England
# 62651   1996       6    15  United Kingdom  Western Europe   England
# 59037   1995       4    19   United States   North America  Oklahoma
# 16681   1982       7    27            Peru   South America  Ayacucho
# 72475   2001       7    24       Sri Lanka      South Asia   Western
#
#                 city                                           location  \
# 50996         London                                                NaN
# 62651     Manchester  Corporation Street outside the Arndale shoppin...
# 59037  Oklahoma City                                                NaN
# 16681       Ayacucho                                                NaN
# 72475     Katunayake  The incident occurred at the Bandaranaike Inte...
#
#           propvalue                                            summary  ...  \
# ...

# %%
q1_df_5.loc[:, 'propvalue'] = q1_df_5['propvalue'].astype(str) #the numbers are mills and bills so i want to write mill or bill

# %%
q1_df_5 = q1_df_5.reset_index(drop=True) #the new dataframe doesn't need the old index

# %%
q1_df_5
# Out:
#    iyear  imonth  iday     country_txt      region_txt provstate  \
# 0   1992       4    10  United Kingdom  Western Europe   England
# 1   1996       6    15  United Kingdom  Western Europe   England
# 2   1995       4    19   United States   North America  Oklahoma
# 3   1982       7    27            Peru   South America  Ayacucho
# 4   2001       7    24       Sri Lanka      South Asia   Western
#
#             city                                           location  \
# 0         London                                                NaN
# 1     Manchester  Corporation Street outside the Arndale shoppin...
# 2  Oklahoma City                                                NaN
# 3       Ayacucho                                                NaN
# 4     Katunayake  The incident occurred at the Bandaranaike Inte...
#
#       propvalue                                            summary  ...  \
# 0  2700000000.0                                                NaN  ...
# ...

# %%
q1_df_5.loc[0, 'propvalue'] = '2.7 billion'
q1_df_5.loc[1, 'propvalue'] = '700 million'
q1_df_5.loc[2, 'propvalue'] = '652 million'
q1_df_5.loc[3, 'propvalue'] = '548 million'
q1_df_5.loc[4, 'propvalue'] = '350 million'

# %%
q1_df_5
# Out:
#    iyear  imonth  iday     country_txt      region_txt provstate  \
# 0   1992       4    10  United Kingdom  Western Europe   England
# 1   1996       6    15  United Kingdom  Western Europe   England
# 2   1995       4    19   United States   North America  Oklahoma
# 3   1982       7    27            Peru   South America  Ayacucho
# 4   2001       7    24       Sri Lanka      South Asia   Western
#
#             city                                           location  \
# 0         London                                                NaN
# 1     Manchester  Corporation Street outside the Arndale shoppin...
# 2  Oklahoma City                                                NaN
# 3       Ayacucho                                                NaN
# 4     Katunayake  The incident occurred at the Bandaranaike Inte...
#
#      propvalue                                            summary  ...  \
# 0  2.7 billion                                                NaN  ...
# ...

# %%
q1_df_5 = q1_df_5.drop('addnotes', axis=1) #columns has all nans

# %%
q1_df_5 = q1_df_5.drop('motive', axis=1) #columns has all nans

# %%
q1_df_5 = q1_df_5.fillna('unknown') #fill the rest of the na's

# %%
q1_df_5
# Out:
#    iyear  imonth  iday     country_txt      region_txt provstate  \
# 0   1992       4    10  United Kingdom  Western Europe   England
# 1   1996       6    15  United Kingdom  Western Europe   England
# 2   1995       4    19   United States   North America  Oklahoma
# 3   1982       7    27            Peru   South America  Ayacucho
# 4   2001       7    24       Sri Lanka      South Asia   Western
#
#             city                                           location  \
# 0         London                                            unknown
# 1     Manchester  Corporation Street outside the Arndale shoppin...
# 2  Oklahoma City                                            unknown
# 3       Ayacucho                                            unknown
# 4     Katunayake  The incident occurred at the Bandaranaike Inte...
#
#      propvalue                                            summary  ...  \
# 0  2.7 billion                                            unknown  ...
# ...

# %%
q1_df_5.to_excel('/Users/jxhn/Desktop/IRONHACK/Week_5/Mid_bootcamp_project/Data/Cleaned/q1_df_5.xlsx', index=False)

# %%
q1_df_5['sizing'] = [27, 10, 6.5, 5.4, 3.5] #saved file but forgot to add 'sizing' column to help with plots/graphs

# %%
q1_df_5
# Out:
#    iyear  imonth  iday     country_txt      region_txt provstate  \
# 0   1992       4    10  United Kingdom  Western Europe   England
# 1   1996       6    15  United Kingdom  Western Europe   England
# 2   1995       4    19   United States   North America  Oklahoma
# 3   1982       7    27            Peru   South America  Ayacucho
# 4   2001       7    24       Sri Lanka      South Asia   Western
#
#             city                                           location  \
# 0         London                                            unknown
# 1     Manchester  Corporation Street outside the Arndale shoppin...
# 2  Oklahoma City                                            unknown
# 3       Ayacucho                                            unknown
# 4     Katunayake  The incident occurred at the Bandaranaike Inte...
#
#      propvalue                                            summary  ...  \
# 0  2.7 billion                                            unknown  ...
# ...

# %%
q1_df_5.to_excel('/Users/jxhn/Desktop/IRONHACK/Week_5/Mid_bootcamp_project/Data/Cleaned/q1_df_5.xlsx', index=False)

# %%
#final saved version of file

# %%
q1_df_5[['summary']]
# Out:
#                                              summary
# 0                                            unknown
# 1  6/15/1996: At or around 11:20 am a truck packe...
# 2                                            unknown
# 3                                            unknown
# 4  07/24/2001: Fourteen militants of the Liberati...
